# %%
import numpy as nsp
a=nsp.array([1,2,3])
b=nsp.array([2,7,-3])
dot_prod=nsp.dot(a,b)
print(dot_prod)
# Out:
# 7

# %%
import sympy as sp
t=sp.Symbol('t')
p_t1=sp.poly(3*t**2+5*t-7,t)
p_t2=sp.poly(5*t**3-7*t,t)
coef1=p_t1.all_coeffs()
coef2=p_t2.all_coeffs()
max_degree=3

coeff1=[0]*(max_degree-len(coef1)+1)+coef1
coeff2=[0]*(max_degree-len(coef2)+1)+coef2
coeff1_mat=sp.Matrix(coeff1)
coeff2_mat=sp.Matrix(coeff2)
print("dotprod=",coeff1_mat.dot(coeff2))
# Out:
# dotprod= -35

# %%
q_t=5*t**3-7*t
r_t=p_t.dot(q_t)
r_t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38480\3307030271.py in <module>
#       1 q_t=5*t**3-7*t
# ----> 2 r_t=p_t.dot(q_t)
#       3 r_t
#
# AttributeError: 'Add' object has no attribute 'dot'

# %%
import scipy.signal as signal
import matplotlib.pyplot as plt

# Define R, L, and C values
R = 1.0  # Resistance in ohms
L = 0.5  # Inductance in henries
C = 0.01  # Capacitance in farads

# Transfer function of an RLC circuit
numerator = [1]
denominator = [L*C, R*C, 1]
system = signal.TransferFunction(numerator, denominator)

# Frequency response
w, mag, phase = signal.bode(system)

# Plotting the Bode plot
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogx(w, mag)  # Magnitude plot
plt.title('Bode Plot')
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Magnitude [dB]')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.semilogx(w, phase)  # Phase plot
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Phase [degrees]')
plt.grid(True)
plt.show()

# %%
1
# Out:
# 1

# %%
import numpy as np 
a=np.array([[1,2,3],[8,-1,4],[6,7,20]])
display(a)
rank_matrix=np.linalg.Rank_Matrix(a)
print(rank_matrix)
# Out:
# array([[ 1,  2,  3],
#        [ 8, -1,  4],
#        [ 6,  7, 20]])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38480\3783641938.py in <module>
#       2 a=np.array([[1,2,3],[8,-1,4],[6,7,20]])
#       3 display(a)
# ----> 4 rank_matrix=np.linalg.Rank_Matrix()
#       5 print(rank_matrix)
#
# AttributeError: module 'numpy.linalg' has no attribute 'Rank_Matrix'

# %%
import numpy as np

arr1 = np.array([[1, 2],
                 [3, 4]])
arr2 = np.array([[5, 6],
                 [7, 8]])

arr_result = np.matmul(arr1, arr2)
print(f'Matrix Product of arr1 and arr2 is:\n{arr_result}')
# Out:
# Matrix Product of arr1 and arr2 is:
# [[19 22]
#  [43 50]]

# %%
import numpy as np

arr1 = np.array([[1, 2],
                 [3, 4]])
arr2 = np.array([[5, 6],
                 [7, 8]])

arr_result = np.multiply(arr1, arr2)
print(arr_result)
# Out:
# [[ 5 12]
#  [21 32]]

# %%
import numpy as np

arr1 = np.array([[1, 2],
                 [3, 4]])
arr2 = np.array([[5, 6],
                 [7, 8]])

arr_result = np.dot(arr1, arr2)
print(f'Dot Product of arr1 and arr2 is:\n{arr_result}')
# Out:
# Dot Product of arr1 and arr2 is:
# [[19 22]
#  [43 50]]

# %%
from pyNastran.bdf.bdf import BDF

# Create a BDF object
bdf = BDF()

# Read a Nastran Bulk Data File (replace 'model.bdf' with your file name)
bdf.read_bdf('model.bdf')

# Display basic information about the model
print("Number of Nodes:", len(bdf.nodes))
print("Number of Elements:", len(bdf.elements))

# Display node coordinates
print("\nNode Coordinates:")
for nid, node in bdf.nodes.items():
    print(f"Node ID: {nid}, Coordinates: {node.xyz}")

# Display element connectivity
print("\nElement Connectivity:")
for eid, element in bdf.elements.items():
    print(f"Element ID: {eid}, Nodes: {element.nodes}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\1754669968.py in <module>
# ----> 1 from pyNastran.bdf.bdf import BDF
#       2
#       3 # Create a BDF object
#       4 bdf = BDF()
#       5
#
# ModuleNotFoundError: No module named 'pyNastran'

# %%
pip install pyNastran
# Out:
# ...
#      ---------------------------------------- 3.3/3.3 MB 107.9 kB/s eta 0:00:00
# ...
#      --------------------------------------- 45.1/45.1 kB 37.8 kB/s eta 0:00:00
# ...
#      ------------------------------------- 313.2/313.2 kB 53.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyNastran.bdf.bdf import BDF

# Create a BDF object
bdf = BDF()

# Read a Nastran Bulk Data File (replace 'model.bdf' with your file name)
bdf.read_bdf('model.bdf')

# Display basic information about the model
print("Number of Nodes:", len(bdf.nodes))
print("Number of Elements:", len(bdf.elements))

# Display node coordinates
print("\nNode Coordinates:")
for nid, node in bdf.nodes.items():
    print(f"Node ID: {nid}, Coordinates: {node.xyz}")

# Display element connectivity
print("\nElement Connectivity:")
for eid, element in bdf.elements.items():
    print(f"Element ID: {eid}, Nodes: {element.nodes}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\1754669968.py in <module>
#       5
#       6 # Read a Nastran Bulk Data File (replace 'model.bdf' with your file name)
# ----> 7 bdf.read_bdf('model.bdf')
#       8
#       9 # Display basic information about the model
#
# ~\miniconda3\lib\site-packages\pyNastran\bdf\bdf.py in read_bdf(self, bdf_filename, validate, xref, punch, read_includes, save_file_structure, encoding)
#     997         self.save_file_structure = save_file_structure
#     998         if bdf_filename and not isinstance(bdf_filename, (StringIO, list)):
# --> 999             check_path(bdf_filename, 'bdf_filename')
#    1000         self._read_bdf_helper(bdf_filename, encoding, punch, read_includes)
#    1001         self.log.debug(f'---starting BDF.read_bdf of {self.bdf_filename}---')
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data for stress (MPa) and strain (unitless)
strain = np.array([0, 0.002, 0.004, 0.006, 0.008, 0.01, 0.012, 0.014, 0.016])
stress = np.array([0, 50, 100, 150, 200, 250, 260, 255, 245])

# Plotting the stress-strain curve
plt.figure()
plt.plot(strain, stress, marker='o', linestyle='-', color='b', label='Stress-Strain Curve')
plt.xlabel('Strain')
plt.ylabel('Stress (MPa)')
plt.title('Stress-Strain Curve')
plt.legend()
plt.grid(True)
plt.show()
